# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num = 20
#Two dimentional array
data = np.random.rand(4, num)
print(data)
# Out:
# [[0.98415489 0.48920426 0.43946705 0.97296285 0.38453669 0.21889903
#   0.75664013 0.92583702 0.66570352 0.39482417 0.73953131 0.55643091
#   0.28348239 0.77382106 0.14163046 0.94410471 0.85159344 0.32941382
#   0.38714715 0.04550076]
#  [0.09823751 0.83346258 0.69242967 0.46219413 0.24539663 0.82178422
#   0.74525043 0.77945801 0.99026198 0.87500828 0.96828928 0.63878358
#   0.4225473  0.77786855 0.47551211 0.04453325 0.34695011 0.81953001
#   0.59986665 0.26058295]
#  [0.84731402 0.71370699 0.95898882 0.49615853 0.6058783  0.57285934
#   0.21583655 0.82116701 0.06994161 0.28128334 0.67193116 0.84334345
#   0.12565173 0.93627337 0.19694184 0.378812   0.01433994 0.82708832
#   0.86974551 0.70500173]
#  [0.9036884  0.83791163 0.80003601 0.20382799 0.28986104 0.56730341
#   0.08389268 0.55958018 0.86000144 0.71914078 0.50053777 0.05437308
#   0.80434479 0.46159209 0.46760345 0.38444588 0.01302212 0.64957548
#   0.5116665  0.95976741]]

# %%
plt.scatter(data[0], data[1], c=data[2], s=data[3]*1000, alpha=0.3, cmap='viridis')
plt.colorbar()

# %%
num =500
data = np.random.rand(num, num)
plt.imshow(data, cmap = 'binary')
plt.colorbar()
